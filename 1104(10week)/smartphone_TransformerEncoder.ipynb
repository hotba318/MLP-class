# %%
import numpy as np
import pandas as pd
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Dense, Flatten, LayerNormalization, Dropout, MultiHeadAttention,
    Add
)
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %%
def load_file(filepath):
    dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
    return dataframe.values

# %%
def load_group(filenames, prefix=''):
    loaded = [load_file(prefix + name) for name in filenames]
    loaded = np.dstack(loaded)
    return loaded

# %%
def load_dataset_group(group, prefix=''):
    filepath = prefix + group + '/Inertial Signals/'
    filenames = [
        'total_acc_x_'+group+'.txt', 'total_acc_y_'+group+'.txt', 'total_acc_z_'+group+'.txt',
        'body_acc_x_'+group+'.txt', 'body_acc_y_'+group+'.txt', 'body_acc_z_'+group+'.txt',
        'body_gyro_x_'+group+'.txt', 'body_gyro_y_'+group+'.txt', 'body_gyro_z_'+group+'.txt'
    ]
    X = load_group(filenames, filepath)
    y = load_file(prefix + group + '/y_'+group+'.txt')
    return X, y

# %%
def load_dataset(prefix=''):
    trainX, trainy = load_dataset_group('train', prefix + '/content/drive/MyDrive/2025-2 MLP/source/UCI HAR Dataset/UCI HAR Dataset/')
    testX, testy = load_dataset_group('test', prefix + '/content/drive/MyDrive/2025-2 MLP/source/UCI HAR Dataset/UCI HAR Dataset/')
    trainy = trainy - 1
    testy = testy - 1
    trainy_one_hot = to_categorical(trainy)
    testy_one_hot = to_categorical(testy)
    return trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot

# %%
trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot = load_dataset()
# Out:
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)

# %%
X_train, X_val, y_train_one_hot, y_val_one_hot, y_train, y_val = train_test_split(
    trainX, trainy_one_hot, trainy, test_size=0.2, random_state=100
)

n_timesteps, n_features, n_outputs = X_train.shape[1], X_train.shape[2], y_train_one_hot.shape[1]

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Multi-Head Attention
    x = MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(inputs, inputs)
    x = Add()([x, inputs])
    x = LayerNormalization(epsilon=1e-6)(x)

    # Feed Forward
    x_ff = Dense(ff_dim, activation='relu')(x)
    x_ff = Dense(inputs.shape[-1])(x_ff)
    x = Add()([x, x_ff])
    x = LayerNormalization(epsilon=1e-6)(x)
    return x

# %%
inputs = Input(shape=(n_timesteps, n_features))
x = transformer_encoder(inputs, head_size=64, num_heads=4, ff_dim=128, dropout=0.1)
x = transformer_encoder(x, head_size=64, num_heads=4, ff_dim=128, dropout=0.1)
flat = Flatten()(x)
dense = Dense(512, activation='relu')(flat)
outputs = Dense(n_outputs, activation='softmax')(dense)

transformer_model = Model(inputs, outputs)
transformer_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
transformer_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 9)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 128, 9)    │      9,993 │ input_layer[0][0… │
# │ (MultiHeadAttentio… │                   │            │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 128, 9)    │          0 │ multi_head_atten… │
# │                     │                   │            │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 128, 9)    │         18 │ add[0][0]         │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128, 128)  │      1,280 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 128, 9)    │      1,161 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 128, 9)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 128, 9)    │         18 │ add_1[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 128, 9)    │      9,993 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 128, 9)    │          0 │ multi_head_atten… │
# │                     │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 128, 9)    │         18 │ add_2[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 128, 128)  │      1,280 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 128, 9)    │      1,161 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 128, 9)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 128, 9)    │         18 │ add_3[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 1152)      │          0 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 512)       │    590,336 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 6)         │      3,078 │ dense_4[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 618,354 (2.36 MB)
#  Trainable params: 618,354 (2.36 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_history = transformer_model.fit(
    X_train,
    y_train_one_hot,
    epochs=30,
    batch_size=32,
    validation_split=0.1
)
# Out:
# Epoch 1/30
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 53s 279ms/step - accuracy: 0.7425 - loss: 0.7008 - val_accuracy: 0.9270 - val_loss: 0.2019
# Epoch 2/30
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 48s 285ms/step - accuracy: 0.9305 - loss: 0.1730 - val_accuracy: 0.9406 - val_loss: 0.1721
# Epoch 3/30
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 83s 292ms/step - accuracy: 0.9405 - loss: 0.1379 - val_accuracy: 0.9372 - val_loss: 0.1412
# Epoch 4/30
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 80s 281ms/step - accuracy: 0.9467 - loss: 0.1337 - val_accuracy: 0.9406 - val_loss: 0.1142
# Epoch 5/30
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 47s 285ms/step - accuracy: 0.9493 - loss: 0.1199 - val_accuracy: 0.9440 - val_loss: 0.1292
# Epoch 6/30
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 46s 278ms/step - accuracy: 0.9496 - loss: 0.1202 - val_accuracy: 0.9508 - val_loss: 0.1152
# Epoch 7/30
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 46s 279ms/step - accuracy: 0.9551 - loss: 0.0965 - val_accuracy: 0.9457 - val_loss: 0.1135
# Epoch 8/30
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 45s 274ms/step - accuracy: 0.9573 - loss: 0.1188 - val_accuracy: 0.9270 - val_loss: 0.1824
# Epoch 9/30
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 47s 281ms/step - accuracy: 0.9323 - loss: 0.1691 - val_accuracy: 0.9049 - val_loss: 0.2246
# Epoch 10/30
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 46s 280ms/step - accuracy: 0.9443 - loss: 0.1252 - val_accuracy: 0.9559 - val_loss: 0.0984
# Epoch 11/30
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 83s 284ms/step - accuracy: 0.9596 - loss: 0.0997 - val_accuracy: 0.9457 - val_loss: 0.1339
# Epoch 12/30
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 46s 275ms/step - accuracy: 0.9604 - loss: 0.0986 - val_accuracy: 0.9593 - val_loss: 0.0971
# Epoch 13/30
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 46s 274ms/step - accuracy: 0.9592 - loss: 0.0989 - val_accuracy: 0.9576 - val_loss: 0.1037
# Epoch 14/30
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 82s 277ms/step - accuracy: 0.9542 - loss: 0.1022 - val_accuracy: 0.9576 - val_loss: 0.1023
# Epoch 15/30
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 83s 284ms/step - accuracy: 0.9610 - loss: 0.0939 - val_accuracy: 0.9457 - val_loss: 0.1120
# Epoch 16/30
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 46s 274ms/step - accuracy: 0.9569 - loss: 0.1005 - val_accuracy: 0.9491 - val_loss: 0.1109
# Epoch 17/30
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 46s 275ms/step - accuracy: 0.9432 - loss: 0.2098 - val_accuracy: 0.9440 - val_loss: 0.1421
# Epoch 18/30
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 83s 282ms/step - accuracy: 0.9380 - loss: 0.1586 - val_accuracy: 0.9559 - val_loss: 0.1128
# Epoch 19/30
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 82s 281ms/step - accuracy: 0.9597 - loss: 0.0996 - val_accuracy: 0.9525 - val_loss: 0.0998
# Epoch 20/30
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 82s 284ms/step - accuracy: 0.9597 - loss: 0.0937 - val_accuracy: 0.9593 - val_loss: 0.1031
# Epoch 21/30
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 45s 274ms/step - accuracy: 0.9653 - loss: 0.0819 - val_accuracy: 0.9542 - val_loss: 0.0998
# Epoch 22/30
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 46s 275ms/step - accuracy: 0.9622 - loss: 0.0858 - val_accuracy: 0.9389 - val_loss: 0.1327
# Epoch 23/30
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 46s 276ms/step - accuracy: 0.9548 - loss: 0.1003 - val_accuracy: 0.9610 - val_loss: 0.0965
# Epoch 24/30
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 47s 284ms/step - accuracy: 0.9667 - loss: 0.0804 - val_accuracy: 0.9423 - val_loss: 0.1251
# Epoch 25/30
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 82s 283ms/step - accuracy: 0.9564 - loss: 0.1120 - val_accuracy: 0.9491 - val_loss: 0.1170
# Epoch 26/30
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 82s 284ms/step - accuracy: 0.9662 - loss: 0.0840 - val_accuracy: 0.9542 - val_loss: 0.1102
# Epoch 27/30
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 44s 267ms/step - accuracy: 0.9699 - loss: 0.0765 - val_accuracy: 0.9508 - val_loss: 0.1119
# Epoch 28/30
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 45s 274ms/step - accuracy: 0.9734 - loss: 0.0682 - val_accuracy: 0.9236 - val_loss: 0.1433
# Epoch 29/30
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 45s 269ms/step - accuracy: 0.9695 - loss: 0.0685 - val_accuracy: 0.9576 - val_loss: 0.1112
# Epoch 30/30
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 45s 274ms/step - accuracy: 0.9686 - loss: 0.0732 - val_accuracy: 0.9542 - val_loss: 0.1086

# %%
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss (Transformer Only)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = model_history.history['accuracy']
val_acc = model_history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy (Transformer Only)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
pred = transformer_model.predict(testX)
pred = np.argmax(pred, axis=-1)
cm = confusion_matrix(testy, pred)
print(cm)
print(accuracy_score(testy, pred))
print(classification_report(testy, pred))
sns.heatmap(cm, annot=True, fmt='.2f')
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 94ms/step
# [[430   6  58   2   0   0]
#  [ 14 428  15   3   7   4]
#  [  2   1 417   0   0   0]
#  [  0   7   0 396  83   5]
#  [  1   6   1  39 485   0]
#  [  0   0   0   0   0 537]]
# 0.9138106549032915
#               precision    recall  f1-score   support
#
#            0       0.96      0.87      0.91       496
#            1       0.96      0.91      0.93       471
#            2       0.85      0.99      0.92       420
#            3       0.90      0.81      0.85       491
#            4       0.84      0.91      0.88       532
#            5       0.98      1.00      0.99       537
#
#     accuracy                           0.91      2947
#    macro avg       0.92      0.91      0.91      2947
# weighted avg       0.92      0.91      0.91      2947
# <Axes: >
